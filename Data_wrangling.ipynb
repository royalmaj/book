# %% [markdown]
# <a href="https://colab.research.google.com/github/royalmaj/book/blob/main/Data_wrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/train.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   name      891 non-null    object
#  3   sex       891 non-null    object
#  4   age       714 non-null    float64
#  5   sibsp     891 non-null    int64
#  6   parch     891 non-null    int64
#  7   ticket    891 non-null    object
#  8   fare      891 non-null    float64
#  9   cabin     204 non-null    object
#  10  embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %%
df.dtypes
# Out:
# survived      int64
# pclass        int64
# name         object
# sex          object
# age         float64
# sibsp         int64
# parch         int64
# ticket       object
# fare        float64
# cabin        object
# embarked     object
# dtype: object

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.isna().sum()
# Out:
# survived      0
# pclass        0
# name          0
# sex           0
# age         177
# sibsp         0
# parch         0
# ticket        0
# fare          0
# cabin       687
# embarked      2
# dtype: int64

# %%
age_mean_value=df['age'].mean()
df['age']=df['age'].fillna(age_mean_value)

# %%
df.drop("cabin",axis=1,inplace=True)

# %%
df.head()
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       sex   age  sibsp  parch            ticket     fare cabin embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
filtered_age = df[df.age>40]
filtered_age
# Out:
#      survived  pclass                                               name  \
# 6           0       1                            McCarthy, Mr. Timothy J
# 11          1       1                           Bonnell, Miss. Elizabeth
# 15          1       2                   Hewlett, Mrs. (Mary D Kingcome)
# 33          0       2                              Wheadon, Mr. Edward H
# 35          0       1                     Holverson, Mr. Alexander Oskar
# ..        ...     ...                                                ...
# 862         1       1  Swift, Mrs. Frederick Joel (Margaret Welles Ba...
# 865         1       2                           Bystrom, Mrs. (Karolina)
# 871         1       1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 873         0       3                        Vander Cruyssen, Mr. Victor
# 879         1       1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
#
#         sex   age  sibsp  parch      ticket     fare cabin embarked
# ...

# %%
merged_df=pd.merge(df.head(2),df.tail(2),how='outer',indicator=True)
merged_df
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       1                              Behr, Mr. Karl Howell
# 3         0       3                                Dooley, Mr. Patrick
#
#       sex   age  sibsp  parch     ticket     fare cabin embarked      _merge
# 0    male  22.0      1      0  A/5 21171   7.2500   NaN        S   left_only
# 1  female  38.0      1      0   PC 17599  71.2833   C85        C   left_only
# 2    male  26.0      0      0     111369  30.0000  C148        C  right_only
# 3    male  32.0      0      0     370376   7.7500   NaN        Q  right_only
