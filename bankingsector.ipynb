# %% [markdown]
# <a href="https://colab.research.google.com/github/royalmaj/book/blob/main/bankingsector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'CustomerID': [1, 2, 3, 4, 5],
    'Age': [25, 30, 35, 40, 45],
    'Income': [50000, 60000, 70000, 80000, 90000],
    'Balance': [1000, 2000, 3000, 4000, 5000]
}

df = pd.DataFrame(data)

plt.figure(figsize=(10, 6))

plt.subplot(1, 2, 1)
plt.scatter(df['Age'], df['Balance'])
plt.title('Age vs. Balance')
plt.xlabel('Age')
plt.ylabel('Balance')

plt.subplot(1, 2, 2)
plt.bar(df['CustomerID'], df['Income'], color='skyblue')
plt.title('Income Distribution')
plt.xlabel('Customer ID')
plt.ylabel('Income')

plt.tight_layout()
plt.show()
